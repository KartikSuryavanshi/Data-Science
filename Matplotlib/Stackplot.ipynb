# %%
import matplotlib.pyplot as plt

# %%
activities = ['Studying' , 'Playing','Watching TV','Sleeping']

# %%
time_spent =[3,2,3,4]# hours in a day
colors = ['blue','red','yellow','pink']
plt.figure(figsize=(6,6))
plt.pie(time_spent, labels=activities,colors=colors,startangle=90 , autopct ="%1.1f%%")
plt.title("After School Activities")
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
# Out:
# (-1.1, 1.1, -1.099978565815544, 1.0999989793245497)

# %%
import matplotlib.pyplot as plt
 
days = [1, 2, 3, 4, 5, 6, 7]  # Days of the week
studying = [3, 4, 3, 5, 4, 3, 4]
playing = [2, 2, 1, 1, 2, 3, 2]
watching_tv = [2, 1, 2, 2, 1, 1, 1]
sleeping = [5, 5, 6, 5, 6, 5, 5]

labels = ['Studying', 'Playing', 'Watching TV', 'Sleeping']
colors = ['skyblue', 'lightgreen', 'gold', 'lightcoral']
 
plt.figure(figsize=(10,6))
plt.stackplot(days, studying,playing,watching_tv,sleeping,labels=labels,colors=colors, alpha =0.4)
# alpha -Transparency level (0 to 1)
plt.legend(loc="upper left")#loc - Position of the legend ('upper left', 'best', etc.)
plt.title('Weekly Activity Tracker')
plt.xlabel('Day')
plt.ylabel('Hours')
plt.grid(True)

# %%
#Try making a stackplot with your own weekly schedule!
import matplotlib.pyplot as plt
 
days = [1, 2, 3, 4, 5, 6, 7]  # Days of the week
gym = [2, 2, 1.5, 2, 1.5, 2, 0]
study = [2, 2, 3, 1, 3, 2, 0]
coding =[1,2,1,2,2,1,3]
playing_with_friends = [4, 4, 3, 1, 2, 4, 3]
watching_tv = [2, 1, 2, 2, 1, 3, 2]
sleeping = [7, 6, 6, 7, 6, 9, 6]

labels = ['Gym', 'Studying', 'Coding','Playing with friends', 'Watching TV', 'Sleeping']
colors = ['pink', 'green', 'silver', 'red','yellow','black']
 
plt.figure(figsize=(10,6))
plt.stackplot(days, gym,study,coding,playing_with_friends,watching_tv,sleeping,labels=labels,colors=colors, alpha =0.5)
plt.legend(loc="best")
plt.title('My Weekly Schedule')
plt.xlabel('Day')
plt.ylabel('Hours')
plt.grid(True)
