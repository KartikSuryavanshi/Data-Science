# %%
#A histogram is a type of plot that shows the distribution of a dataset.
#It’s especially useful for visualizing the frequency of numerical data within specified ranges (called bins).

# %%
plt.hist(data, bins=10)  # 10 equal-width bins
plt.hist(data, bins=[10, 20, 30, 40, 60, 100])  # Custom age bins

# %%
import matplotlib.pyplot as plt

data = [
    34, 88, 86, 65, 77, 47, 45, 37, 25, 35,
    25, 25, 82, 10, 12, 94, 19, 33, 60, 65,
    44, 57, 30, 5, 24, 81, 18, 33, 23, 97,
    23, 48, 59, 19, 38, 87, 32, 10, 96, 31,
    97, 31, 28, 26, 15, 22, 25, 90, 33, 12,
    0, 26, 23, 36, 40, 39, 21, 96, 33, 39,
    65, 28, 58, 18, 38, 43, 99, 40, 33, 23,
    73, 65, 59, 45, 3, 38, 30, 27, 30, 10,
    97, 33, 44, 84, 21, 84, 39, 33, 64, 95,
    90, 39, 100, 26, 26, 95, 32, 32, 30, 87
]

plt.hist(data, edgecolor='black') #edgecolor parameter adds borders to the bars, improving clarity
plt.xlabel('Marks')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import matplotlib.pyplot as plt
import numpy as np
 

ages = [
    34, 28, 36, 45, 27, 27, 45, 37, 25, 35,
    25, 25, 32, 10, 12, 24, 19, 33, 20, 15,
    44, 27, 30, 15, 24, 31, 18, 33, 23, 27,
    23, 48, 29, 19, 38, 17, 32, 10, 16, 31,
    37, 31, 28, 26, 15, 22, 25, 40, 33, 12,
    33, 26, 23, 36, 40, 39, 21, 26, 33, 39,
    25, 28, 18, 18, 38, 43, 29, 40, 33, 23,
    33, 45, 29, 45, 3, 38, 30, 27, 30, 10,
    27, 33, 44, 24, 21, 24, 39, 33, 24, 35,
    30, 39, 22, 26, 26, 15, 32, 32, 30, 27
]

bins = [10, 20, 30, 40, 50, 60, 70]

plt.hist(ages, bins=bins, edgecolor='black')
plt.title('Age Distribution of YouTube Viewers')
plt.xlabel('Age Group')
plt.ylabel('Number of Viewers')
plt.grid(True, linestyle='--', alpha=0.5)

# %%
plt.hist(ages, bins=bins, edgecolor='black')
plt.axvline(np.mean(ages), color='red', linestyle='--', linewidth=2, label='Average Age')#Vertical reference line
#axvline to mark a specific value like the average age or a threshold
plt.legend()
plt.title('Age Distribution with Mean Line')
# Out:
# Text(0.5, 1.0, 'Age Distribution with Mean Line')
