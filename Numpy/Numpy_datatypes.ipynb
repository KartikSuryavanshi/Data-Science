# %%
import numpy as np

# %%
arr = np.array([23,4,5,2])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.astype("float64")
# Out:
# array([23.,  4.,  5.,  2.])

# %%
arr2 =np.array([23,4,5,2],dtype="float32")

# %%
arr2
# Out:
# array([23.,  4.,  5.,  2.], dtype=float32)

# %%
arr2.nbytes
# Out:
# 16

# %%
arr.nbytes
# Out:
# 32

# %%
arr_int64 = np.array([1, 2, 3], dtype=np.int64)
arr_int32 = np.array([1, 2, 3], dtype=np.int32)

print(arr_int64.nbytes)  # Output: 24 bytes (3 elements * 8 bytes each)
print(arr_int32.nbytes)  # Output: 12 bytes (3 elements * 4 bytes each)
# Out:
# 24
# 12
