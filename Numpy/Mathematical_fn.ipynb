# %%
import numpy as np

# %%
arr = np.array([3,4,5,6,9,6])

# %%
np.mean(arr)
# Out:
# 4.5

# %%
np.min(arr)
# Out:
# 3

# %%
np.max(arr)
# Out:
# 6

# %%
np.std(arr)
# Out:
# 1.118033988749895

# %%
np.var(arr)
# Out:
# 1.25

# %%
np.sum(arr)
# Out:
# 18

# %%
np.median(arr)
# Out:
# 4.5

# %%
np.prod(arr)
# Out:
# 360

# %%
np.percentile(arr,50)
# Out:
# 4.5

# %%
np.argmin(arr)#min -index
# Out:
# 0

# %%
np.unique(arr)
# Out:
# array([3, 4, 5, 6, 9])

# %%
np.cumsum(arr) #(3+4=7 , 7+5 =12 ...)
# Out:
# array([ 3,  7, 12, 18, 27, 33])
