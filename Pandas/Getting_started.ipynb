# %%
import pandas as pd #Series: A one-dimensional labeled array (like a single column in Excel)
#DataFrame: A two-dimensional labeled table (like an Excel sheet or SQL table)

# %%
s1 = pd.Series([66,77,78,88,44])

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
print(s1)
# Out:
# 0    66
# 1    77
# 2    78
# 3    88
# 4    44
# dtype: int64

# %%
s2 = pd.Series([66,77,78,88,44],index=["harry","shubh","rohan","akash","naina"])

# %%
s2
# Out:
# harry    66
# shubh    77
# rohan    78
# akash    88
# naina    44
# dtype: int64

# %%
s2["harry"]
# Out:
# 66

# %%
data = {
    "name": ["Alice", "Bob", "Charlie"], #each column is a series
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %%
df.index # Row labels
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns  # Column labels
# Out:
# Index(['name', 'age', 'city'], dtype='object')
